# %%
import pandas as pd 
df = pd.read_csv("C:\\city.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 seller_type  bedroom layout_type      property_type  \
# 0           0       OWNER        2         BHK          Apartment
# 1           1       OWNER        1          RK   Studio Apartment
# 2           2       OWNER        3         BHK          Apartment
# 3           3       OWNER        2         BHK  Independent House
# 4           4       OWNER        2         BHK  Independent House
#
#       locality   price  area    furnish_type     bathroom       city
# 0     Bodakdev  20,000  1450       Furnished  2 bathrooms  Ahmedabad
# 1      CG Road   7,350   210  Semi-Furnished  1 bathrooms  Ahmedabad
# 2      Jodhpur  22,000  1900     Unfurnished  3 bathrooms  Ahmedabad
# 3       Sanand  13,000  1285  Semi-Furnished  2 bathrooms  Ahmedabad
# 4  Navrangpura  18,000  1600       Furnished  2 bathrooms  Ahmedabad

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193476 entries, 0 to 193475
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     193476 non-null  int64
#  1   seller_type    193476 non-null  object
#  2   bedroom        193476 non-null  int64
#  3   layout_type    193476 non-null  object
#  4   property_type  193476 non-null  object
#  5   locality       193476 non-null  object
#  6   price          193476 non-null  object
#  7   area           193476 non-null  int64
#  8   furnish_type   193476 non-null  object
#  9   bathroom       193476 non-null  object
#  10  city           193476 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 16.2+ MB

# %%
df.shape
# Out:
# (193476, 11)

# %%
df=df.drop('Unnamed: 0',axis=1)
df.tail()
# Out:
#        seller_type  bedroom layout_type     property_type       locality  \
# 193471       OWNER        1         BHK         Apartment      Chinchwad
# 193472       OWNER        1          RK  Studio Apartment  Wadgaon Sheri
# 193473       OWNER        1         BHK         Apartment        Kothrud
# 193474       AGENT        1         BHK         Apartment          Wakad
# 193475       AGENT        2         BHK         Apartment         Alandi
#
#          price  area    furnish_type     bathroom  city
# 193471  13,250   650  Semi-Furnished  1 bathrooms  Pune
# 193472   7,000   350     Unfurnished  1 bathrooms  Pune
# 193473   8,500   389  Semi-Furnished  1 bathrooms  Pune
# 193474  16,500   670  Semi-Furnished  2 bathrooms  Pune
# 193475  12,000   800     Unfurnished  2 bathrooms  Pune

# %%
df.seller_type.nunique()
# Out:
# 3

# %%
df.layout_type.nunique()
# Out:
# 2

# %%
df.property_type.nunique()
# Out:
# 6

# %%
df.locality.nunique()
# Out:
# 4151

# %%
df.furnish_type.nunique()
# Out:
# 3

# %%
df.city.nunique()
# Out:
# 8

# %%
import numpy as np
import re
for i in range(0,193476):
    df.price[i]=re.sub('[^0-9]','',df.price[i])
df.info
# Out:
# C:\Users\Arka\AppData\Local\Temp/ipykernel_9984/4044071355.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.price[i]=re.sub('[^0-9]','',df.price[i])
# <bound method DataFrame.info of        seller_type  bedroom layout_type      property_type       locality  \
# 0            OWNER        2         BHK          Apartment       Bodakdev
# 1            OWNER        1          RK   Studio Apartment        CG Road
# 2            OWNER        3         BHK          Apartment        Jodhpur
# 3            OWNER        2         BHK  Independent House         Sanand
# 4            OWNER        2         BHK  Independent House    Navrangpura
# ...            ...      ...         ...                ...            ...
# 193471       OWNER        1         BHK          Apartment      Chinchwad
# ...

# %%
df.price = np.int64(df.price)

# %%
df.head()
# Out:
#   seller_type  bedroom layout_type      property_type     locality  price  \
# 0       OWNER        2         BHK          Apartment     Bodakdev  20000
# 1       OWNER        1          RK   Studio Apartment      CG Road   7350
# 2       OWNER        3         BHK          Apartment      Jodhpur  22000
# 3       OWNER        2         BHK  Independent House       Sanand  13000
# 4       OWNER        2         BHK  Independent House  Navrangpura  18000
#
#    area    furnish_type     bathroom       city
# 0  1450       Furnished  2 bathrooms  Ahmedabad
# 1   210  Semi-Furnished  1 bathrooms  Ahmedabad
# 2  1900     Unfurnished  3 bathrooms  Ahmedabad
# 3  1285  Semi-Furnished  2 bathrooms  Ahmedabad
# 4  1600       Furnished  2 bathrooms  Ahmedabad

# %%
for i in range(193476):
    if df.price[i]<1000:
        df.drop(i,inplace=True)
        print(i)
df.price
# Out:
# 22
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 1679
# 1742
# 1743
# 2072
# 2133
# 2134
# 2169
# 2170
# 2179
# 2221
# 2222
# 2238
# 2239
# 2252
# 2253
# 2254
# 2255
# 2258
# 2279
# 2280
# 2354
# 2355
# 2359
# 2361
# 2364
# 2365
# 2394
# 3420
# 3423
# 3427
# 3624
# 3635
# 4976
# 4984
# 4990
# 4994
# 4995
# 4998
# 4999
# 5011
# 5019
# 5021
# 5028
# 5031
# 5049
# 5053
# 5248
# 5249
# 5250
# 5251
# 5252
# 5254
# 5256
# 5257
# 5258
# 5269
# 5270
# 5272
# 5273
# 5274
# 5285
# 5292
# 5569
# 5798
# 5854
# 5934
# 5970
# 6134
# 6150
# 6171
# 6175
# 6176
# 6180
# 6182
# 6183
# 6184
# 6271
# 6280
# 6281
# 6283
# 6284
# 6295
# 6296
# 6298
# 6306
# 6322
# 6323
# 6326
# 6327
# 6328
# 6329
# 6331
# 6337
# 6341
# 6342
# 6345
# 6346
# 6347
# 6350
# 6353
# 6354
# 6355
# 6983
# 7019
# 7044
# 7070
# 7084
# 7114
# 7134
# 7135
# 7136
# 7138
# 7140
# 7564
# 7826
# 7839
# 7847
# 7849
# 7874
# 7994
# 7996
# 7997
# 7998
# 8000
# 8001
# 8002
# 8006
# 8007
# 8239
# ...

# %%
df.reset_index(drop=True,inplace=True)
df.tail()
# Out:
#        seller_type  bedroom layout_type     property_type       locality  \
# 178516       OWNER        1         BHK         Apartment      Chinchwad
# 178517       OWNER        1          RK  Studio Apartment  Wadgaon Sheri
# 178518       OWNER        1         BHK         Apartment        Kothrud
# 178519       AGENT        1         BHK         Apartment          Wakad
# 178520       AGENT        2         BHK         Apartment         Alandi
#
#         price  area    furnish_type     bathroom  city
# 178516  13250   650  Semi-Furnished  1 bathrooms  Pune
# 178517   7000   350     Unfurnished  1 bathrooms  Pune
# 178518   8500   389  Semi-Furnished  1 bathrooms  Pune
# 178519  16500   670  Semi-Furnished  2 bathrooms  Pune
# 178520  12000   800     Unfurnished  2 bathrooms  Pune

# %%
df.drop('locality',axis=1,inplace=True)
df.head()
# Out:
#   seller_type  bedroom layout_type      property_type  price  area  \
# 0       OWNER        2         BHK          Apartment  20000  1450
# 1       OWNER        1          RK   Studio Apartment   7350   210
# 2       OWNER        3         BHK          Apartment  22000  1900
# 3       OWNER        2         BHK  Independent House  13000  1285
# 4       OWNER        2         BHK  Independent House  18000  1600
#
#      furnish_type     bathroom       city
# 0       Furnished  2 bathrooms  Ahmedabad
# 1  Semi-Furnished  1 bathrooms  Ahmedabad
# 2     Unfurnished  3 bathrooms  Ahmedabad
# 3  Semi-Furnished  2 bathrooms  Ahmedabad
# 4       Furnished  2 bathrooms  Ahmedabad

# %%
df.drop('bathroom',axis=1,inplace=True)
df.head()
# Out:
#   seller_type  bedroom layout_type      property_type  price  area  \
# 0       OWNER        2         BHK          Apartment  20000  1450
# 1       OWNER        1          RK   Studio Apartment   7350   210
# 2       OWNER        3         BHK          Apartment  22000  1900
# 3       OWNER        2         BHK  Independent House  13000  1285
# 4       OWNER        2         BHK  Independent House  18000  1600
#
#      furnish_type       city
# 0       Furnished  Ahmedabad
# 1  Semi-Furnished  Ahmedabad
# 2     Unfurnished  Ahmedabad
# 3  Semi-Furnished  Ahmedabad
# 4       Furnished  Ahmedabad

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
col=df.columns
col
# Out:
# Index(['seller_type', 'bedroom', 'layout_type', 'property_type', 'price',
#        'area', 'furnish_type', 'city'],
#       dtype='object')

# %%
l=[x for x in col if df[x].dtype=='object']
for i in l:
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    seller_type  bedroom  layout_type  property_type  price  area  \
# 0            2        2            0              0  20000  1450
# 1            2        1            1              4   7350   210
# 2            2        3            0              0  22000  1900
# 3            2        2            0              2  13000  1285
# 4            2        2            0              2  18000  1600
#
#    furnish_type  city
# 0             0     0
# 1             1     0
# 2             2     0
# 3             1     0
# 4             0     0

# %%
df.tail()
# Out:
#         seller_type  bedroom  layout_type  property_type  price  area  \
# 178516            2        1            0              0  13250   650
# 178517            2        1            1              4   7000   350
# 178518            2        1            0              0   8500   389
# 178519            0        1            0              0  16500   670
# 178520            0        2            0              0  12000   800
#
#         furnish_type  city
# 178516             1     7
# 178517             2     7
# 178518             1     7
# 178519             1     7
# 178520             2     7

# %%
df.to_csv('cleaned_data.csv')

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
mm =MinMaxScaler()

# %%
mm.fit(df)
df = mm.transform(df)
df = pd.DataFrame(df,columns=col)
df.head()
# Out:
#    seller_type   bedroom  layout_type  property_type     price      area  \
# 0          1.0  0.071429          0.0            0.0  0.191831  0.078056
# 1          1.0  0.000000          1.0            0.8  0.064038  0.011166
# 2          1.0  0.142857          0.0            0.0  0.212036  0.102330
# 3          1.0  0.071429          0.0            0.4  0.121116  0.069155
# 4          1.0  0.071429          0.0            0.4  0.171627  0.086147
#
#    furnish_type  city
# 0           0.0   0.0
# 1           0.5   0.0
# 2           1.0   0.0
# 3           0.5   0.0
# 4           0.0   0.0

# %%
df.tail()
# Out:
#         seller_type   bedroom  layout_type  property_type     price      area  \
# 178516          1.0  0.000000          0.0            0.0  0.123641  0.034901
# 178517          1.0  0.000000          1.0            0.8  0.060502  0.018718
# 178518          1.0  0.000000          0.0            0.0  0.075656  0.020822
# 178519          0.0  0.000000          0.0            0.0  0.156474  0.035980
# 178520          0.0  0.071429          0.0            0.0  0.111013  0.042993
#
#         furnish_type  city
# 178516           0.5   1.0
# 178517           1.0   1.0
# 178518           0.5   1.0
# 178519           0.5   1.0
# 178520           1.0   1.0

# %%
wcss=[]
for i in range(1,11):
    km = KMeans(n_clusters=i,random_state=42)
    km.fit(df)
    wcss.append(km.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel('Number of cluster')
plt.ylabel('wcss')
# Out:
# Text(0, 0.5, 'wcss')

# %%
km = KMeans(n_clusters=5,random_state=42)
label=km.fit_predict(df)
label
# Out:
# array([0, 3, 0, ..., 0, 4, 2])

# %%
for i in range(0,5):
    print(df[label==i])
# Out:
#         seller_type   bedroom  layout_type  property_type     price      area  \
# 0               1.0  0.071429          0.0            0.0  0.191831  0.078056
# 2               1.0  0.142857          0.0            0.0  0.212036  0.102330
# 3               1.0  0.071429          0.0            0.4  0.121116  0.069155
# 4               1.0  0.071429          0.0            0.4  0.171627  0.086147
# 5               1.0  0.000000          0.0            0.0  0.075656  0.030586
# ...             ...       ...          ...            ...       ...       ...
# 178513          1.0  0.000000          0.0            0.0  0.050400  0.030586
# 178514          1.0  0.000000          0.0            0.0  0.146371  0.026810
# 178515          1.0  0.000000          0.0            0.2  0.080707  0.018718
# 178516          1.0  0.000000          0.0            0.0  0.123641  0.034901
# 178518          1.0  0.000000          0.0            0.0  0.075656  0.020822
#
#         furnish_type  city
# ...
